# %% [markdown]
# ## Water Quality - Ocean Monitoring Program
#
# Ocean water quality data, including bacteriological sampling for fecal indicator bacteria as well as physical, chemical, and biological parameters observed throughout the region. Samples are collected as part of The City’s Ocean Monitoring Program, which monitors the effects of treated wastewater effluent on the local marine environment. The OMP extends 340 square miles total from northern San Diego to northern Baja California, Mexico, and encompasses the shoreline seaward approximately 10 miles, to depths of over 500 meters.
#
# [source](https://data.sandiego.gov/datasets/monitoring-ocean-water-quality/)

# %% [markdown]
# Data source: https://data.sandiego.gov/datasets/monitoring-ocean-water-quality/

# %%
# %pip install meteostat

# %%
# %pip install plotly

# %%
# %pip install dash

# %%
# %pip install jupyter-dash

# %%
import numpy as np
import datetime as dt
import meteostat as ms

from dash import Dash, html, dcc, Input, Output
from jupyter_dash import JupyterDash
import plotly.express as px
import plotly.graph_objects as go

from urllib.request import urlopen
import json
import webbrowser

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import geopandas as gpd
# from shapely.geometry import Point, Polygon, mapping

# %% [markdown]
# # water quality data

# %%
data_dict = pd.read_csv("./data/water_quality_dictionary_datasd.csv")
data_dict
# Out:
#          field                                        description  \
# 0       sample                                   Unique sample ID
# 1      station  Unique location ID where sample was collected....
# 2      depth_m                                    Depth in meters
# 3  date_sample                          Date sample was collected
# 4         time                          Time sample was collected
# 5      project          Outfall region where sample was collected
# 6    parameter                              Factor being recorded
# 7    qualifier                                Qualifier for value
# 8        value                                       Result value
# 9        units                              Units of result value
#
#                                      possible_values
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  PLOO (PL): Point Loma Ocean Outfall; SBOO: Sou...
# 6  fluorometry; DENSITY; DO; ENTERO; FECAL; OG; P...
# 7                                <, >, e, LA, ND, NS
# 8                                                NaN
# 9     %; C; CFU/100 ml; mg/L; pH; ppt; sigma-t; ug/L

# %%
data_dict.iloc[6,2]
# Out:
# 'fluorometry; DENSITY; DO; ENTERO; FECAL; OG; PH; SALINITY; SUSO; TEMP; TOTAL; pct_light'

# %%
locs = pd.read_csv("./data/reference_stations_water_quality.csv")
locs
# Out:
#     station       lat       long
# 0       I25  32.56117 -117.14800
# 1       I26  32.57450 -117.14700
# 2       S10  32.54330 -117.12500
# 3       S11  32.56130 -117.13200
# 4        S4  32.53530 -117.12500
# ..      ...       ...        ...
# 152      B6  32.82833 -117.29250
# 153      A3  32.65167 -117.29717
# 154      A4  32.68450 -117.30700
# 155     A15  32.66833 -117.28167
# 156     A16  32.67633 -117.28417
#
# [157 rows x 3 columns]

# %%
data = pd.read_csv("./data/water_quality_2020_2021_datasd.csv")
data
# Out:
#            sample station  depth_m date_sample         time project parameter  \
# 0      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO    ENTERO
# 1      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     TOTAL
# 2      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     FECAL
# 3      2001018680      S4      NaN  2020-01-01          NaN    SBOO     TOTAL
# 4      2001018680      S4      NaN  2020-01-01          NaN    SBOO     FECAL
# ...           ...     ...      ...         ...          ...     ...       ...
# 70158  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO    ENTERO
# 70159  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO     TOTAL
# 70160  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     FECAL
# 70161  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO    ENTERO
# 70162  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     TOTAL
#
#       qualifier  value       units
# 0             e  220.0  CFU/100 mL
# 1            NR    NaN  CFU/100 mL
# 2            NR    NaN  CFU/100 mL
# 3            NS    NaN  CFU/100 mL
# 4            NS    NaN  CFU/100 mL
# ...         ...    ...         ...
# 70158         e   14.0  CFU/100 mL
# 70159         <  200.0  CFU/100 mL
# 70160         <    2.0  CFU/100 mL
# 70161         e    4.0  CFU/100 mL
# 70162         <   20.0  CFU/100 mL
#
# [70163 rows x 10 columns]

# %%
data.nunique()
# Out:
# sample         15333
# station          104
# depth_m           16
# date_sample      369
# time             383
# project            2
# parameter         10
# qualifier          7
# value           8190
# units              8
# dtype: int64

# %%
# there are more stations than in the measurement
# but thankfully every station with a measurement is accounted for
len(set(data['station']).difference(set(locs['station'])))
# Out:
# 0

# %%
pd.to_datetime(data['date_sample']).min()
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
pd.to_datetime(data['date_sample']).max()
# Out:
# Timestamp('2021-12-29 00:00:00')

# %%
data = pd.merge(
    data,
    locs,
    how='left',
    left_on='station',
    right_on='station'
)

data
# Out:
#            sample station  depth_m date_sample         time project parameter  \
# 0      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO    ENTERO
# 1      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     TOTAL
# 2      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     FECAL
# 3      2001018680      S4      NaN  2020-01-01          NaN    SBOO     TOTAL
# 4      2001018680      S4      NaN  2020-01-01          NaN    SBOO     FECAL
# ...           ...     ...      ...         ...          ...     ...       ...
# 70158  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO    ENTERO
# 70159  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO     TOTAL
# 70160  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     FECAL
# 70161  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO    ENTERO
# 70162  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     TOTAL
#
#       qualifier  value       units       lat       long
# 0             e  220.0  CFU/100 mL  32.56130 -117.13200
# 1            NR    NaN  CFU/100 mL  32.56130 -117.13200
# 2            NR    NaN  CFU/100 mL  32.56130 -117.13200
# 3            NS    NaN  CFU/100 mL  32.53530 -117.12500
# 4            NS    NaN  CFU/100 mL  32.53530 -117.12500
# ...         ...    ...         ...       ...        ...
# 70158         e   14.0  CFU/100 mL  32.73945 -117.25499
# 70159         <  200.0  CFU/100 mL  32.73945 -117.25499
# 70160         <    2.0  CFU/100 mL  32.74667 -117.25402
# 70161         e    4.0  CFU/100 mL  32.74667 -117.25402
# 70162         <   20.0  CFU/100 mL  32.74667 -117.25402
#
# [70163 rows x 12 columns]

# %%
# pretty balanced measurements
data['parameter'].value_counts()
# Out:
# ENTERO         8680
# FECAL          7489
# TOTAL          7479
# TEMP           6645
# DO             6645
# PH             6645
# CHLOROPHYLL    6645
# XMS            6645
# SALINITY       6645
# DENSITY        6645
# Name: parameter, dtype: int64

# %%
sns.displot(data[data['parameter']=='ENTERO']['value'], kind="kde");

# %% [markdown]
# # Get Precipitation data
# - utilizes meteostat library which sources data from NOAA

# %%
# lat lon for nearby area
crown_point = (32.786670, -117.238620)

# start = dt(2020, 1, 1)
# end = dt(2021, 12, 29)


# going to use rolling sum so want 7 days prior
start = pd.to_datetime(data['date_sample'].min()).to_pydatetime() - dt.timedelta(days=7)
end = pd.to_datetime(data['date_sample'].max()).to_pydatetime()

# get closest weather station
diego = ms.Point(crown_point[0], crown_point[1], 70)

# call the api
rain_data = ms.Daily(diego, start, end)
rain_data = rain_data.fetch()['prcp']

# move timestamp into column
rain_data = rain_data.reset_index()

# convert datetype for joining
rain_data['time'] = rain_data['time'].astype(str)

rain_data = rain_data.rename(columns={'time': 'date', 'prcp': 'prcp_mm'})
rain_data['week_prcp_mm'] = rain_data['prcp_mm'].rolling(7).sum()
# rolling function has some unexpected behavior that yields negative numbers very close to zero
rain_data['week_prcp_mm'] = np.around(rain_data['week_prcp_mm'], decimals=2)
rain_data = rain_data.dropna().reset_index(drop=True)
rain_data
# Out:
#            date  prcp_mm  week_prcp_mm
# 0    2019-12-31      0.0          32.5
# 1    2020-01-01      0.0          32.5
# 2    2020-01-02      0.0           0.0
# 3    2020-01-03      0.0           0.0
# 4    2020-01-04      0.0           0.0
# ..          ...      ...           ...
# 725  2021-12-25      4.6          25.4
# 726  2021-12-26      2.0          27.4
# 727  2021-12-27      1.3          28.7
# 728  2021-12-28      2.0          30.7
# 729  2021-12-29      6.9          37.6
#
# [730 rows x 3 columns]

# %%
print('min: ', rain_data['prcp_mm'].min())
print('max: ', rain_data['prcp_mm'].max())

sns.displot(rain_data['prcp_mm'], kind='kde');
# Out:
# min:  0.0
# max:  29.5

# %%
print('min: ', rain_data['week_prcp_mm'].min())
print('max: ', rain_data['week_prcp_mm'].max())

sns.displot(rain_data['week_prcp_mm'], kind='kde');
# Out:
# min:  -0.0
# max:  91.2

# %%
# bring rain data
data = pd.merge(
    data,
    rain_data,
    how='left',
    left_on='date_sample',
    right_on='date'
)

# delete superfluous column
data = data.drop(['date'], axis=1)
data
# Out:
#            sample station  depth_m date_sample         time project parameter  \
# 0      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO    ENTERO
# 1      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     TOTAL
# 2      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     FECAL
# 3      2001018680      S4      NaN  2020-01-01          NaN    SBOO     TOTAL
# 4      2001018680      S4      NaN  2020-01-01          NaN    SBOO     FECAL
# ...           ...     ...      ...         ...          ...     ...       ...
# 70158  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO    ENTERO
# 70159  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO     TOTAL
# 70160  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     FECAL
# 70161  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO    ENTERO
# 70162  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     TOTAL
#
#       qualifier  value       units       lat       long  prcp_mm  week_prcp_mm
# 0             e  220.0  CFU/100 mL  32.56130 -117.13200      0.0          32.5
# 1            NR    NaN  CFU/100 mL  32.56130 -117.13200      0.0          32.5
# 2            NR    NaN  CFU/100 mL  32.56130 -117.13200      0.0          32.5
# 3            NS    NaN  CFU/100 mL  32.53530 -117.12500      0.0          32.5
# 4            NS    NaN  CFU/100 mL  32.53530 -117.12500      0.0          32.5
# ...         ...    ...         ...       ...        ...      ...           ...
# 70158         e   14.0  CFU/100 mL  32.73945 -117.25499      6.9          37.6
# 70159         <  200.0  CFU/100 mL  32.73945 -117.25499      6.9          37.6
# 70160         <    2.0  CFU/100 mL  32.74667 -117.25402      6.9          37.6
# 70161         e    4.0  CFU/100 mL  32.74667 -117.25402      6.9          37.6
# 70162         <   20.0  CFU/100 mL  32.74667 -117.25402      6.9          37.6
#
# [70163 rows x 14 columns]

# %%
# calculate max for each measurement
# will help with colorscale
max_values = data.groupby(['parameter'])[['value']].max().reset_index()
max_values = max_values.rename(columns={'value':'max_value'})
max_values
# Out:
#      parameter  max_value
# 0  CHLOROPHYLL     62.310
# 1      DENSITY     26.301
# 2           DO     13.600
# 3       ENTERO  12000.000
# 4        FECAL  13000.000
# 5           PH      8.710
# 6     SALINITY     34.209
# 7         TEMP     23.930
# 8        TOTAL  16000.000
# 9          XMS     94.190

# %%
# bring max vlaues
data = pd.merge(
    data,
    max_values,
    how='left',
    left_on='parameter',
    right_on='parameter'
)

data
# Out:
#            sample station  depth_m date_sample         time project parameter  \
# 0      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO    ENTERO
# 1      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     TOTAL
# 2      2001018683     S11      NaN  2020-01-01  9:18:00 PST    SBOO     FECAL
# 3      2001018680      S4      NaN  2020-01-01          NaN    SBOO     TOTAL
# 4      2001018680      S4      NaN  2020-01-01          NaN    SBOO     FECAL
# ...           ...     ...      ...         ...          ...     ...       ...
# 70158  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO    ENTERO
# 70159  2112291249    D8-B      NaN  2021-12-29  9:36:00 PST    PLOO     TOTAL
# 70160  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     FECAL
# 70161  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO    ENTERO
# 70162  2112291250      D9      NaN  2021-12-29  9:22:00 PST    PLOO     TOTAL
#
#       qualifier  value       units       lat       long  prcp_mm  \
# 0             e  220.0  CFU/100 mL  32.56130 -117.13200      0.0
# 1            NR    NaN  CFU/100 mL  32.56130 -117.13200      0.0
# 2            NR    NaN  CFU/100 mL  32.56130 -117.13200      0.0
# 3            NS    NaN  CFU/100 mL  32.53530 -117.12500      0.0
# 4            NS    NaN  CFU/100 mL  32.53530 -117.12500      0.0
# ...         ...    ...         ...       ...        ...      ...
# 70158         e   14.0  CFU/100 mL  32.73945 -117.25499      6.9
# 70159         <  200.0  CFU/100 mL  32.73945 -117.25499      6.9
# 70160         <    2.0  CFU/100 mL  32.74667 -117.25402      6.9
# 70161         e    4.0  CFU/100 mL  32.74667 -117.25402      6.9
# 70162         <   20.0  CFU/100 mL  32.74667 -117.25402      6.9
#
#        week_prcp_mm  max_value
# 0              32.5    12000.0
# 1              32.5    16000.0
# 2              32.5    13000.0
# 3              32.5    16000.0
# 4              32.5    13000.0
# ...             ...        ...
# 70158          37.6    12000.0
# 70159          37.6    16000.0
# 70160          37.6    13000.0
# 70161          37.6    12000.0
# 70162          37.6    16000.0
#
# [70163 rows x 15 columns]

# %% [markdown]
# # Build Dashboard
# create a scatter/point plot of the measurement locations
#
# [money documentation](https://plotly.com/python/mapbox-layers/?_gl=1*1qyo6lu*_ga*OTMzNzQ4MDQxLjE2NzY2MjA3MjY.*_ga_6G7EE0JNSC*MTY3OTU0MzIxMC4yNS4xLjE2Nzk1NDQ4NzIuMC4wLjA.)

# %%
features = sorted(data['parameter'].unique())

for feat in features:
    print(f"feature_description['{feat}'] = ''")
# Out:
# feature_description['CHLOROPHYLL'] = ''
# feature_description['DENSITY'] = ''
# feature_description['DO'] = ''
# feature_description['ENTERO'] = ''
# feature_description['FECAL'] = ''
# feature_description['PH'] = ''
# feature_description['SALINITY'] = ''
# feature_description['TEMP'] = ''
# feature_description['TOTAL'] = ''
# feature_description['XMS'] = ''

# %%
# feature_description = {feat:'' for feat in features}

feature_description = {}
feature_description['CHLOROPHYLL'] = 'indicator for photosynthetic plankton'
feature_description['DENSITY'] = 'density of coliform (bacteria)'
feature_description['DO'] = 'dissolved oxygen'
feature_description['ENTERO'] = 'enteroccus (bacteria), indicator of sewage'
feature_description['FECAL'] = 'fecal matter in water, indicator of sewage'
feature_description['PH'] = 'acidity / basicness of water'
feature_description['SALINITY'] = 'disolved salt content'
feature_description['TEMP'] = 'water temperature in degrees Celsius'
feature_description['TOTAL'] = 'unclear'
feature_description['XMS'] = 'transmissivity of light in water'

feature_description
# Out:
# {'CHLOROPHYLL': 'indicator for photosynthetic plankton',
#  'DENSITY': 'density of coliform (bacteria)',
#  'DO': 'dissolved oxygen',
#  'ENTERO': 'enteroccus (bacteria), indicator of sewage',
#  'FECAL': 'fecal matter in water, indicator of sewage',
#  'PH': 'acidity / basicness of water',
#  'SALINITY': 'disolved salt content',
#  'TEMP': 'water temperature in degrees Celsius',
#  'TOTAL': 'unclear',
#  'XMS': 'transmissivity of light in water'}

# %% [markdown]
# help with these descriptions from 2015 report by this same project:
# https://www.ibwc.gov/Files/2015_SBOO_AnnualReceivingWatersMonitoringAssessmentReport.pdf
# ![image.png](attachment:image.png)

# %%
# create str labels for tooltip
data['unit_values'] = data['value'].astype(str) + ' ' + data['units']

# %%
# create str labels for measurement scale
data['unit_labels'] = data['parameter'] + ' ' + data['units']

# %%
# help(px.colors.sequential)
# #help(px.colors.diverging)

# %%
# px.colors.diverging.swatches()

# %%
# px.colors.sequential.swatches()

# %%
# help(px.scatter_mapbox)

# %% [markdown]
# # now move into dash and add filter for parameter

# %%
# SOLUTION

#app = Dash(__name__) #if wanted to build in python ide
app = JupyterDash(__name__)


###
# configure visualization
###
colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

feature_description = {}
feature_description['CHLOROPHYLL'] = 'indicator for photosynthetic plankton'
feature_description['DENSITY'] = 'density of coliform (bacteria)'
feature_description['DO'] = 'dissolved oxygen'
feature_description['ENTERO'] = 'enteroccus (bacteria), indicator of sewage'
feature_description['FECAL'] = 'fecal matter in water, indicator of sewage'
feature_description['PH'] = 'acidity / basicness of water'
feature_description['SALINITY'] = 'disolved salt content'
feature_description['TEMP'] = 'water temperature in degrees Celsius'
feature_description['TOTAL'] = 'unclear'
feature_description['XMS'] = 'transmissivity of light in water'


###
# SEND TO SERVER
###
app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1( # header1
        children='Ocean Water Quality',
        style={
            'textAlign': 'center',
            'color': colors['text'],
        }
    ),
    # subtitle
    html.Div(# subtitle
        children='''
        San Diego Coast from 2020-2021 \n(select parameter from dropdown and hover over station to view details).
        ''',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),
    
    #html.Div([
    
    dcc.Dropdown(
        sorted(data['parameter'].unique()),
        'TEMP', # this should be the default starting measure
        id='parameter-dropdown',
        style={
            'textAlign': 'center',
            'color': colors['text'],
            'position': 'relative',
            #'width': '80%',
            #'display': 'inline-block',
#             'top': '50%',
#             'left': '50%',
#             'transform': 'translate(-50%, -50%)',
#             'height': '50%',
            'width': '80%',
            'z-index': '1',
            'margin-left': 'auto',
            'margin-right': 'auto',
        }
    ),
    #]),
    
    html.Div([
        dcc.Graph(id='sd-county',
                  style={
#                   #'display': 'inline-block',
#                   'vertical-align': 'center',
#                   'width': '100%',
#                   'height': '500px', # inflexible solution, want it to take up remainder of screen space
                  'position': 'absolute',
                  'top': '60%',
                  'left': '50%',
                  'transform': 'translate(-50%, -50%)',
                  #'height': '60%',
                  'height': '60vh',
                  'width': '80%',
                  }
    )]),
        
        html.Div([
        html.Br(),
        html.Label('Weekly Rain Accumulation (mm)', 
                   style={
                       'color': colors['text'],
                       'textAlign': 'center',
                   }),
        dcc.Slider(
            0, # minimum
            np.ceil(data['week_prcp_mm'].max()), # maximum
            step=None,
            id='rain--slider',
            value=0, # start at no rain
            marks={str(num): str(num) for num in np.ceil(data['week_prcp_mm']).unique().astype(int)},# dictionary comprehension 
            vertical=False, #verticalHeight=600,
            dots=False,
            tooltip={'placement': 'bottom', 'always_visible': True}
        )
]),

    
    # subtitle
    html.Div(# data description
        children='''
        include a description of the data
        ''',
        id='describe-param',
        style={
            'textAlign': 'center',
            'color': colors['text'],
            'z-index': '2'
        }
    ),

    
])


###
# first chart: choropleth
###

def create_scatter(data):
    
    fig = px.scatter_mapbox(data, 
                            lat="lat", 
                            lon="long", 
                            hover_name="station", 
                            hover_data={"value":False, "unit_values":True, "n_measurements":True, "lat":False, "long":False},
                            labels={'value':list(data['unit_labels'])[0],"n_measurements":"# of readings", "unit_values": "reading"},
                            color="value",
                            #color_continuous_scale="haline", # I think this is a good one
                            color_continuous_scale="deep", # possibly better
                            range_color=(0, data['max_value'].max()),
                            size="n_measurements",
                            size_max=15,
                            opacity=0.9,
                            zoom=8, 
                            height=300,
                           )
    
    fig.update_layout(
        #title='San Diego Coast',
        #autosize=True, hovermode='closest',
        mapbox_style="open-street-map",
        #mapbox_style="carto-positron",
        #mapbox_style="carto-darkmatter",
        #mapbox_style="stamen-terrain",
        #mapbox_style="stamen-toner",
        #mapbox_style="stamen-watercolor",
        margin={"r":0,"t":0,"l":0,"b":0},
        #mapbox_bounds={"west": -180, "east": -50, "south": 20, "north": 90}, # plotly version 5.11 needed
        coloraxis_colorbar_x=0.10, # move to left side of viz
    )
    

    fig.update_geos(
        fitbounds='locations', visible=True, # initializes the zoom to just our locations
                   )
    #fig.show()
    return fig

###
# CALLBACK for Scatter mapbox #
###
@app.callback(
    Output('sd-county', 'figure'),
    Input('parameter-dropdown', 'value'),
    Input('rain--slider', 'value'),
)
def update_scatter(selected_parameter, rain_value):
    
    # filtered on parameter
    filtered_data = data[data['parameter']==selected_parameter]
    # and filtered on rain amount within 1 mm
    filtered_data = filtered_data[filtered_data['week_prcp_mm'].between(rain_value-1, rain_value)]
    # calculate number of observations
    
    # create the number of measurements for a site, specific to each parameter
    measurement_counts = filtered_data.groupby(['station', 'parameter'])[['sample']].nunique().reset_index()
    measurement_counts = measurement_counts.rename(columns={'sample': 'n_measurements'})   
    # bring back to original dataframe
    filtered_data = pd.merge(
        filtered_data,
        measurement_counts,
        how='left',
        left_on=['station', 'parameter'],
        right_on=['station', 'parameter']
        )
    
    return create_scatter(filtered_data)

###
# CALLBACK for data description
###
@app.callback(
    Output('describe-param', 'children'),
    Input('parameter-dropdown', 'value')
)

def update_description(value):
    description = feature_description[value]
    return f'{value}: {description}'


if __name__ == '__main__':
    #app.run(debug=True)
    # supposedly deprecated
    app.run_server(mode='jupyterlab', 
                   host="localhost",
                   port=8051,
                   debug=False, # change to False on deploy
                   dev_tools_hot_reload=True # changes should occur in real time
                  ) # click the link to view the chart
    
# will automatically launch in new tab
webbrowser.open("http://localhost:8051/")
# Out:
# Dash is running on http://localhost:8051/
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:8051
# Press CTRL+C to quit
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_alive_10edb526-4e14-4ecd-83e2-4f7893e1f4da HTTP/1.1" 200 -
# True
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_9_0m1679089843.js HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Mar/2023 12:14:39] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:14:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:15:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:16:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:17:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:18:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:19:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:20:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:21:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:22:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:23:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:24:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:25:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:26:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:27:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:37] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [24/Mar/2023 12:28:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:28:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:39] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [24/Mar/2023 12:29:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:29:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:30:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:31:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:53] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:32:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:33:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:34:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:35:29] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:36:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:37:29] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:38:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:39:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:40:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:41:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:42:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:43:26] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:44:29] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:45:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:46:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:47:29] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:48:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:49:29] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:50:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:51:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:14] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:23] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [24/Mar/2023 12:52:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:26] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [24/Mar/2023 12:52:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:32] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [24/Mar/2023 12:52:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET /_favicon.ico?v=2.9.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Mar/2023 12:52:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:52:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:41] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:44] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:47] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:56] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:53:59] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:02] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:05] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:08] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:11] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:14] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:20] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:23] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:26] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:29] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:32] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:35] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:54:38] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:55:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:56:26] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:57:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:58:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 12:59:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:00:41] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:01:29] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:02:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:03:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:04:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:05:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:06:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:07:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:08:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:09:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:10:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:11:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 13:12:24] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
# 127.0.0.1 - - [24/Mar/2023 14:34:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:34:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:35:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:36:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:37:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:38:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:39:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:40:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:41:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:42:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:43:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:44:58] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:01] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:04] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:07] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:10] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:13] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:16] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:19] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:22] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:25] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:28] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:31] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:34] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:37] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:40] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:43] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:46] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:49] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:52] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:55] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2023 14:45:58] "GET /_reload-hash HTTP/1.1" 200 -
